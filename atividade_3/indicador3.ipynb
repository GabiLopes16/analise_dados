# %%
import pandas as pd

# %%
path = r"H:\PYTHON\3_ETAPA\atividade_3\Tabela_3_Areas_gerais_de_formacao_na_graduacao.xlsx"

dados = pd.read_excel(path, header=None)

# %%
print(dados)
# Out:
#                                                     0         1         2  \
# 0   Tabela 10063 - Pessoas com nível superior comp...       NaN       NaN
# 1        Brasil, Grande Região e Unidade da Federação     Total       NaN
# 2                                                 NaN     Total    Homens
# 3                                              Brasil  25854291  10478534
# 4                                               Norte   1525166    590558
# 5                                            Nordeste   4748933   1744994
# 6                                             Sudeste  12828829   5391638
# 7                                                 Sul   4338861   1768855
# 8                                        Centro-Oeste   2412502    982489
# 9                                            Rondônia    164632     62766
# 10                                               Acre     84300     33291
# 11                                           Amazonas    342566    141059
# ...

# %%
df = dados.copy()

# %%
df = dados.copy()

# Homens e mulheres por região com curso superior
tabela_curso_superior = df.copy()

tabela_curso_superior.to_excel("curso_superior.xlsx", index=False)


print("=== ESTATÍSTICAS: CURSO SUPERIOR ===")
display(tabela_curso_superior.describe())
# Out:
# === ESTATÍSTICAS: CURSO SUPERIOR ===
#                                                         0      1       2  \
# count                                                  36     35      34
# unique                                                 36     34      34
# top     Tabela 10063 - Pessoas com nível superior comp...  Total  Homens
# freq                                                    1      2       1
#
#                3                                               4       5  \
# count         34                                              35      34
# unique        34                                              35      34
# top     Mulheres  Ciência, Tecnologia, Engenharias e Matemática   Homens
# freq           1                                               1       1
#
#                6                                               7       8  \
# count         34                                              35      34
# ...

# %%
# 2. Filtrar os dados da área de Tecnologia/Exatas
tabela_tecnologia = dados.copy() 

tabela_tecnologia.to_excel("tecnologia.xlsx", index=False)
print("=== ESTATÍSTICAS: CIÊNCIA, TECNOLOGIA, ENGENHARIA E MATEMÁTICA ===")
display(tabela_tecnologia.describe())
# Out:
# === ESTATÍSTICAS: CIÊNCIA, TECNOLOGIA, ENGENHARIA E MATEMÁTICA ===
#                                                         0      1       2  \
# count                                                  36     35      34
# unique                                                 36     34      34
# top     Tabela 10063 - Pessoas com nível superior comp...  Total  Homens
# freq                                                    1      2       1
#
#                3                                               4       5  \
# count         34                                              35      34
# unique        34                                              35      34
# top     Mulheres  Ciência, Tecnologia, Engenharias e Matemática   Homens
# freq           1                                               1       1
#
#                6                                               7       8  \
# count         34                                              35      34
# ...

# %%
tabela_educacao_saude = dados.copy()

tabela_educacao_saude.to_excel("educacao_saude.xlsx", index=False)

print("=== ESTATÍSTICAS: EDUCAÇÃO, SERVIÇOS, SAÚDE E BEM-ESTAR ===")
display(tabela_educacao_saude.describe())
# Out:
# === ESTATÍSTICAS: EDUCAÇÃO, SERVIÇOS, SAÚDE E BEM-ESTAR ===
#                                                         0      1       2  \
# count                                                  36     35      34
# unique                                                 36     34      34
# top     Tabela 10063 - Pessoas com nível superior comp...  Total  Homens
# freq                                                    1      2       1
#
#                3                                               4       5  \
# count         34                                              35      34
# unique        34                                              35      34
# top     Mulheres  Ciência, Tecnologia, Engenharias e Matemática   Homens
# freq           1                                               1       1
#
#                6                                               7       8  \
# count         34                                              35      34
# ...
