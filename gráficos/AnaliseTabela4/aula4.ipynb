# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = r"H:\analiseDados\AnaliseTabela4\CD2022_Populacao_2010_Compatibilizada_20231222.xlsx"

# %%
dados_brutos = pd.read_excel(path, header=2)

# %%
tabela_tratada = dados_brutos.iloc[0:5570,1:]

# %%
tabela_tratada.columns
# Out:
# Index(['UF', 'COD. UF', 'COD. MUNIC', 'NOME DO MUNICÍPIO',
#        'População Município 2010\n(Sinopse)',
#        'População 2010 (Alterações de Limites até 2022)1',
#        'População Censo 2022'],
#       dtype='str')

# %%
tabela_tratada
# Out:
#       UF  COD. UF  COD. MUNIC      NOME DO MUNICÍPIO  \
# 0     RO     11.0        15.0  Alta Floresta D'Oeste
# 1     RO     11.0        23.0              Ariquemes
# 2     RO     11.0        31.0                 Cabixi
# 3     RO     11.0        49.0                 Cacoal
# 4     RO     11.0        56.0             Cerejeiras
# ...   ..      ...         ...                    ...
# 5565  GO     52.0     22005.0             Vianópolis
# 5566  GO     52.0     22054.0         Vicentinópolis
# 5567  GO     52.0     22203.0               Vila Boa
# 5568  GO     52.0     22302.0          Vila Propício
# 5569  DF     53.0       108.0               Brasília
#
#       População Município 2010\n(Sinopse)  \
# 0                                 24392.0
# 1                                 90353.0
# 2                                  6313.0
# 3                                 78574.0
# 4                                 17029.0
# ...                                   ...
# 5565                              12548.0
# 5566                               7371.0
# 5567                               4735.0
# 5568                               5145.0
# 5569                            2570160.0
#
#       População 2010 (Alterações de Limites até 2022)1  População Censo 2022
# 0                                              24392.0               21494.0
# 1                                              90353.0               96833.0
# 2                                               6313.0                5351.0
# 3                                              78574.0               86887.0
# 4                                              17029.0               15890.0
# ...                                                ...                   ...
# 5565                                           12548.0               14956.0
# 5566                                            7373.0                8768.0
# 5567                                            4735.0                4215.0
# 5568                                            5145.0                5815.0
# 5569                                         2572159.0             2817381.0
#
# [5570 rows x 7 columns]

# %%
# 5. Crie uma tabela de população agregada por estado
pop_estado = dados_brutos.groupby("UF")[["População 2010 (Alterações de Limites até 2022)1", "População Censo 2022"]].sum().reset_index()

# Faz a diferença (crescimento populacional)
pop_estado["diferenca"] = pop_estado["População Censo 2022"] - pop_estado["População 2010 (Alterações de Limites até 2022)1"]

# %%
# 6. Organize essa tabela por população que mais cresceu (Decrescente)
pop_estado_ordenado = pop_estado.sort_values(by="diferenca", ascending=False)

# %%
# 7. Salve essa tabela nova em csv na pasta do seu projeto
pop_estado_ordenado.to_csv("populacao_agregada_estado.csv", sep=";", index=False)

# %%
pop_estado_ordenado
# Out:
#                                                    UF  \
# 27                                                 SP
# 25                                                 SC
# 9                                                  GO
# 19                                                 PR
# 11                                                 MG
# 13                                                 MT
# 15                                                 PA
# 2                                                  AM
# 5                                                  CE
# 7                                                  ES
# 12                                                 MS
# 17                                                 PE
# 6                                                  DF
# 16                                                 PB
# 10                                                 MA
# 24                                                 RS
# 23                                                 RR
# 18                                                 PI
# 26                                                 SE
# 21                                                 RN
# 28                                                 TO
# 4                                                  BA
# 0                                                  AC
# 20                                                 RJ
# 3                                                  AP
# 22                                                 RO
# 1                                                  AL
# 8   Fonte: IBGE. Diretoria de Pesquisas - DPE -  C...
# 14  Nota: Para o cálculo das taxas de crescimento ...
#
#     População 2010 (Alterações de Limites até 2022)1  População Censo 2022  \
# 27                                        41262199.0            44411238.0
# 25                                         6248436.0             7610361.0
# 9                                          6001789.0             7056495.0
# 19                                        10444526.0            11444380.0
# 11                                        19597330.0            20539989.0
# 13                                         3035122.0             3658649.0
# 15                                         7581051.0             8120131.0
# 2                                          3483985.0             3941613.0
# 5                                          8451644.0             8794957.0
# 7                                          3514952.0             3833712.0
# 12                                         2449024.0             2757013.0
# 17                                         8796055.0             9058931.0
# 6                                          2572159.0             2817381.0
# 16                                         3766528.0             3974687.0
# 10                                         6574789.0             6776699.0
# 24                                        10693929.0            10882965.0
# 23                                          450479.0              636707.0
# 18                                         3119097.0             3271199.0
# 26                                         2067852.0             2210004.0
# 21                                         3168027.0             3302729.0
# 28                                         1383445.0             1511460.0
# 4                                         14017071.0            14141626.0
# 0                                           733559.0              830018.0
# 20                                        15989929.0            16055174.0
# 3                                           669526.0              733759.0
# 22                                         1562409.0             1581196.0
# 1                                          3120887.0             3127683.0
# 8                                                0.0                   0.0
# 14                                               0.0                   0.0
#
#     diferenca
# 27  3149039.0
# 25  1361925.0
# 9   1054706.0
# 19   999854.0
# 11   942659.0
# 13   623527.0
# 15   539080.0
# 2    457628.0
# 5    343313.0
# 7    318760.0
# 12   307989.0
# 17   262876.0
# 6    245222.0
# 16   208159.0
# 10   201910.0
# 24   189036.0
# 23   186228.0
# 18   152102.0
# 26   142152.0
# 21   134702.0
# 28   128015.0
# 4    124555.0
# 0     96459.0
# 20    65245.0
# 3     64233.0
# 22    18787.0
# 1      6796.0
# 8         0.0
# 14        0.0

# %%
# 8. Agora trabalhe por município
# Faz a diferença diretamente na tabela bruta
dados_brutos["diferenca"] = dados_brutos["População Censo 2022"] - dados_brutos["População 2010 (Alterações de Limites até 2022)1"]

# %%
# 9. Organize essa tabela por população que mais cresceu (Decrescente)
pop_municipio_ordenado = dados_brutos.sort_values(by="diferenca", ascending=False)

# %%
# 10. Salve essa tabela nova em csv na pasta do seu projeto
pop_municipio_ordenado.to_csv("populacao_municipio_ordenado.csv", sep=";", index=False)

# %%
pop_municipio_ordenado
# Out:
#       Unnamed: 0                                                 UF  COD. UF  \
# 111          NaN                                                 AM     13.0
# 5569         NaN                                                 DF     53.0
# 3829         NaN                                                 SP     35.0
# 3848         NaN                                                 SP     35.0
# 5417         NaN                                                 GO     52.0
# ...          ...                                                ...      ...
# 2162         NaN                                                 BA     29.0
# 5570         NaN                                                NaN      NaN
# 5571         NaN  Nota: Para o cálculo das taxas de crescimento ...      NaN
# 5572         NaN                                                NaN      NaN
# 5573         NaN  Fonte: IBGE. Diretoria de Pesquisas - DPE -  C...      NaN
#
#       COD. MUNIC NOME DO MUNICÍPIO  População Município 2010\n(Sinopse)  \
# 111       2603.0            Manaus                            1802014.0
# 5569       108.0          Brasília                            2570160.0
# 3829     50308.0         São Paulo                           11253503.0
# 3848     52205.0          Sorocaba                             586625.0
# 5417      8707.0           Goiânia                            1302001.0
# ...          ...               ...                                  ...
# 2162     27408.0          Salvador                            2675656.0
# 5570         NaN               NaN                                  NaN
# 5571         NaN               NaN                                  NaN
# 5572         NaN               NaN                                  NaN
# 5573         NaN               NaN                                  NaN
#
#       População 2010 (Alterações de Limites até 2022)1  População Censo 2022  \
# 111                                          1802014.0             2063689.0
# 5569                                         2572159.0             2817381.0
# 3829                                        11253503.0            11451999.0
# 3848                                          586816.0              723682.0
# 5417                                         1301912.0             1437366.0
# ...                                                ...                   ...
# 2162                                         2675656.0             2417678.0
# 5570                                               NaN                   NaN
# 5571                                               NaN                   NaN
# 5572                                               NaN                   NaN
# 5573                                               NaN                   NaN
#
#       diferenca
# 111    261675.0
# 5569   245222.0
# 3829   198496.0
# 3848   136866.0
# 5417   135454.0
# ...         ...
# 2162  -257978.0
# 5570        NaN
# 5571        NaN
# 5572        NaN
# 5573        NaN
#
# [5574 rows x 9 columns]

# %%
#Barras: população 2022 por UF
fig, ax = plt.subplots(figsize=(10, 10))
ordem = pop_estado_ordenado.sort_values("População Censo 2022", ascending=False)
sns.barplot(data=ordem, y="UF", x="População Censo 2022", ax=ax, color="steelblue")
ax.set_title("População 2022 por UF")
ax.set_xlabel("Habitantes")
ax.set_ylabel("UF")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\12501174\AppData\Local\Temp\ipykernel_2040\2994310447.py:8: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
